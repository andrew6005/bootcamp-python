# %%
#Data Type
#int, float, str , boolean

x=3 
print(type(x))
# Out:
# <class 'int'>

# %%
print(10+3)
# Out:
# 13

# %%
y="hello"
print(y+3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 y="hello"
# ----> 2 print(y+3)
#
# TypeError: can only concatenate str (not "int") to str

# %%
a = 10
a+=3
print(a)
# Out:
# 13

# %%
s= "java"
s+="python"
print("a"+s)
# Out:
# ajavapython

# %%
print(0.1+0.1)
print(round)

# %%
word='python'
print(word[0])
print(word[-1])
print(word[1:3])
# Out:
# p
# n
# yt

# %%
student_name="steven"
print(student_name.count('s'))
print(student_name.isdigit())
print(student_name.startswith('s'))
print(student_name.startswith('t'))


score="93"
print(score.isdigit())
# Out:
# 1
# False
# True
# False
# True

# %%
x=10

if  x>9:
  print(x)
if(x<20 and x>1):
    print(x)
if(x>0):
  print("positive")
else:
    print("negative")

score=92
if(score>=90):
  grade='A'
print(grade)
# Out:
# 10
# 10
# positive
# A

# %%
number =3
if(number%2==1):
  print("odd")
else:
  print("Even")
# Out:
# odd

# %%
fruits =['apple','banana','lemon']
print(fruits)
print(type(fruits))
print(fruits[0],fruits[2])
# Out:
# ['apple', 'banana', 'lemon']
# <class 'list'>
# apple lemon
