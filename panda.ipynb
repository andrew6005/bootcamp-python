# %%
import pandas as pd

pd.Series([2,8,9,40])
print(type(ages))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2
#       3 pd.Series([2,8,9,40])
#       4 print(type(ages))
#
# ModuleNotFoundError: No module named 'pandas'
