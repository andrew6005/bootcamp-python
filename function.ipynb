# %%
def hello():
  print("hello world")

# %%
def sum(x,y):
  return x+y
print(sum(10,3))
print(sum('hello','world'))
# Out:
# 13
# helloworld

# %%
def subtract(x,y):
  return x-y
print(subtract(20,9))

# %%
from unittest import result


def operate(x,y):
  return x+y, x-y,x*y,x/y
result1,result2,result3,result4 = operate(10,2)
print(result1)
print(result2)
print(result3)
print(result4)

# %%
def is_odd(x: int)-> bool:
  return x % 2 ==1
print (is_odd(9))
# Out:
# True

# %%
number =[9,43,45,5]
number_set=set[int](number)
print(type(number_set))

number_list= list(number_set)
print(type(number_list))
# Out:
# <class 'set'>
# <class 'list'>

# %%
square_formula = lambda x:x **2
print(square_formula(10))
# Out:
# 100

# %%
ages = [2,34,56,75,43,74,98]
elderly_ages = list (filter(lambda x:x>65,ages))
print(elderly_ages)
# Out:
# [75, 74, 98]

# %%
names = ["John","Jennie","Tommy","Lucas","Leo"]
#names = list[str](filter[str](lambda))
new_names = list(filter(lambda name : name.startwith("J")and len(names)>5,names))
print(new_names)
# Out:
#   Cell In[15], line 3
#     new_names = list set(filter(lambda name : name.startwith("J")and len(names)>5,names))
#                      ^
# SyntaxError: invalid syntax
