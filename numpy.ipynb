# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
print(df['Age'].isnull().any())
print(df['Age'].isnull().any())
print(df['Age'].isnull())
print(df.dropna(subset=['Age']))
# Out:
# True
# True
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# ...

# %%
df_for_refill = df.copy()
df_for_refill['Age']= df_for_refill['Age'].fillna('N/A')
print(df_for_refill['Age'].isnull().any)
# Out:
# <bound method Series.any of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool>

# %%
df_result = df.groupby('Sex')['Age'].mean()
print(df_result)
df_result = df.groupby(['Survied','Sex'])['Age'].max()
print(df_result)

df_person['dob'] = pd.to_datetime(df_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_result = df.groupby('Sex')['Age'].mean()
#       2 print(df_result)
#       3 df_result = df.groupby(['Survied','Sex'])['Age'].max()
#       4 print(df_result)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import Table,Column,MetaData,Integer,String,Float,Date ,BigInteger

# %%
#part 2
df_person = pd.read_csv("person.csv")
print(df_person.head())
print(df_person.info())
# Out:
#    id  nmae         dob   salary
# 0   1  john  2000-01-02  25000.0
# 1   2  john  2005-03-07  50000.0
# 2   3   leo  2005-03-07  90000.0
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      3 non-null      int64
#  1   nmae    3 non-null      str
#  2   dob     3 non-null      str
#  3   salary  3 non-null      float64
# dtypes: float64(1), int64(1), str(2)
# memory usage: 228.0 bytes
# None

# %%
df_result = (pd.read_sql ("select * from users"))
print (df_result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df_result = (pd.read_sql ("select * from users"))
#       2 print (df_result)
#
# TypeError: read_sql() missing 1 required positional argument: 'con'
